# %% [markdown]
# ### KDD
#
# O kdd possui 5 fases:
#
# * Seleção: que consiste em selecionar um conjunto de dados que farão partes da análise
#
# * Pré-Processamento: consiste em fazer a verificação e limpeza dos dados
#
# * Tranformação: Aplicação de técnicas de transformação (normalização, agregação, criação de novos atributos, redução, etc). Tais ações são feitas sobre atributos úteis nos dados
#
# * Mineração dos Dados: Consiste na aplicação de algoritimos e técnicas para identificar padrões nos dados e verificar hipóteses
#
# * Análise exploratória de Dados: tem como objetivo examinar os dados previamente à aplicação de qualquer técnica estatística. Para realizar a análise exploratória, é necessário conhecer tecnicamente seus dados, o que eles representam e como eles são classificados (IMPORTANTE ENTENDER SEUS DADOS!)

# %% [markdown]
# ### Demonstração

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Gerar valores aleatórios e plotar um histograma

# %%
minutos_por_dia = np.random.randint(0,60,30)

print(minutos_por_dia)

ax = sns.histplot(minutos_por_dia)

ax.set(xlabel='Minutos por Dia', ylabel='Qtd Vezes')

plt.show()
# Out:
# [20 49 25  1 48 40 43 38  6 20 56 50 12 57  5 25 33 56 21 12 13 42 40 42
#   3  4 34 58 47 22]

# %% [markdown]
# ### Instalar uma nova biblioteca para anánise exploratória

# %%
import sweetviz

# %%
arquivo = "https://raw.githubusercontent.com/JeffSackmann/tennis_atp/master/atp_matches_2021.csv"

dados = pd.read_csv(arquivo)

display(dados)
# Out:
#      tourney_id    tourney_name surface  draw_size tourney_level  \
# 0     2021-0096  Tokyo Olympics    Hard         64             A
# 1     2021-0096  Tokyo Olympics    Hard         64             A
# 2     2021-0096  Tokyo Olympics    Hard         64             A
# 3     2021-0096  Tokyo Olympics    Hard         64             A
# 4     2021-0096  Tokyo Olympics    Hard         64             A
# ...         ...             ...     ...        ...           ...
# 2728  2021-9210       Laver Cup    Hard          8             A
# 2729  2021-9210       Laver Cup    Hard          8             A
# 2730  2021-9210       Laver Cup    Hard          8             A
# 2731  2021-9210       Laver Cup    Hard          8             A
# 2732  2021-9210       Laver Cup    Hard          8             A
#
#       tourney_date  match_num  winner_id  winner_seed winner_entry  ...  \
# 0         20210724        237     126207          NaN          NaN  ...
# ...

# %%
# Gera uma análise dos dados, gerando um arquivo html na raiz , descrevendo todos os atributos do DF
eda = sweetviz.analyze(dados)
eda.show_html()
# Out:
# Feature: tourney_date                        |█▏        | [ 12%]   00:00 -> (00:01 left)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Gera uma análise dos dados, gerando um arquivo html na raiz , descrevendo todos os atributos do DF
# ----> 2 eda = sweetviz.analyze(dados)
#       3 eda.show_html()
#
# File c:\Users\PICHAU\AppData\Local\Programs\Python\Python313\Lib\site-packages\sweetviz\sv_public.py:12, in analyze(source, target_feat, feat_cfg, pairwise_analysis)
#       8 def analyze(source: Union[pd.DataFrame, Tuple[pd.DataFrame, str]],
#       9             target_feat: str = None,
#      10             feat_cfg: FeatureConfig = None,
#      11             pairwise_analysis: str = 'auto'):
# ---> 12     report = sweetviz.DataframeReport(source, target_feat, None,
# ...

# %% [markdown]
# ### Gera uma matriz de correlação de Pearson

# %%
mask = np.triu(np.ones_like(dados.corr(), dtype=np.bool))

plt.figure(figsize=(20,20))
sns.heatmap(dados.corr(), mask=mask, square=True)
plt.show()
# Out:
# Feature: tourney_date                        |█▏        | [ 12%]   05:17 -> (38:47 left)
# Feature: tourney_date                        |█▏        | [ 12%]   03:37 -> (26:34 left)
# Feature: tourney_date                        |█▏        | [ 12%]   01:45 -> (12:54 left)
# Feature: tourney_date                        |█▏        | [ 12%]   01:33 -> (11:29 left)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 mask = np.triu(np.ones_like(dados.corr(), dtype=np.bool))
#       3 plt.figure(figsize=(20,20))
#       4 sns.heatmap(dados.corr(), mask=mask, square=True)
#
# File c:\Users\PICHAU\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# ...
